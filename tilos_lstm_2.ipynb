# %%
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None

import matplotlib.pyplot as plt

import os
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

import tensorflow as tf
import collections
from local_utils import *

# %%
#load data
def load_data():
    data = pd.read_csv('./data/tilos_hourly.csv')
    data['datetime'] = pd.to_datetime(data['datetime'])
    data['value'] = data['value'].astype(np.float32)
    #rename the datetime column to 'DHH'
    data = data.rename(columns={'datetime':'DHH'})
    data = data.rename(columns={'value':'kW/h'})
    return data

df = load_data()
df
# Out:
#                      DHH        kW/h
# 0    2021-01-01 00:00:00  250.770004
# 1    2021-01-01 01:00:00  231.770004
# 2    2021-01-01 02:00:00  222.869995
# 3    2021-01-01 03:00:00  221.369995
# 4    2021-01-01 04:00:00  220.429993
# ...                  ...         ...
# 4219 2021-06-25 19:00:00  456.130005
# 4220 2021-06-25 20:00:00  502.700012
# 4221 2021-06-25 21:00:00  533.200012
# 4222 2021-06-25 22:00:00  526.369995
# 4223 2021-06-25 23:00:00  517.599976
#
# [4224 rows x 2 columns]

# %%
WINDOW_SIZE = 24
STEP_SIZE = 1

train_data, test_data, scaler = train_test_split_and_scale(df, 0.8)
X, Y = create_sliding_window (train_data, WINDOW_SIZE, STEP_SIZE)
X_test, Y_test = create_sliding_window (test_data, WINDOW_SIZE, STEP_SIZE)

print(X.shape, Y.shape, X_test.shape, Y_test.shape)
# Out:
# (3355, 24, 1) (3355,) (821, 24, 1) (821,)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping


def create_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Input((WINDOW_SIZE,1)),
        tf.keras.layers.LSTM(32),
        tf.keras.layers.Dropout(0.1),
        tf.keras.layers.Dense(32),
        tf.keras.layers.Dense(16),
        tf.keras.layers.Dense(1)
    ])
    return model

early_stopping = EarlyStopping(
    monitor='loss',  # Metric to monitor (e.g., validation loss)
    patience=10,         # Number of epochs with no improvement to wait
    restore_best_weights=True  # Restores the model weights from the epoch with the best performance
)

# %%
loss = tf.keras.losses.MeanSquaredError()

metrics = [
    tf.keras.metrics.MeanAbsoluteError(),
    tf.keras.metrics.RootMeanSquaredError()
]

# Define and compile model
model = create_model()
model.compile(loss=loss,
                optimizer=Adam(learning_rate=0.001),
                metrics=metrics)

# Train model
model.fit(X, Y, epochs=100, callbacks=[early_stopping])

# Evaluation
test_loss, test_mae, test_rmse, = model.evaluate(X_test, Y_test)
train_loss, train_mae, train_rmse = model.evaluate(X, Y)
# Out:
# Epoch 1/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0684 - mean_absolute_error: 0.1911 - root_mean_squared_error: 0.2463
# Epoch 2/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0115 - mean_absolute_error: 0.0839 - root_mean_squared_error: 0.1071
# Epoch 3/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - mean_absolute_error: 0.0681 - root_mean_squared_error: 0.0875
# Epoch 4/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0521 - root_mean_squared_error: 0.0707
# Epoch 5/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0475 - root_mean_squared_error: 0.0648
# Epoch 6/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0419 - root_mean_squared_error: 0.0594
# Epoch 7/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0414 - root_mean_squared_error: 0.0581
# Epoch 8/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0390 - root_mean_squared_error: 0.0541
# Epoch 9/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0375 - root_mean_squared_error: 0.0532
# Epoch 10/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0393 - root_mean_squared_error: 0.0560
# Epoch 11/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0393 - root_mean_squared_error: 0.0564
# Epoch 12/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0380 - root_mean_squared_error: 0.0528
# Epoch 13/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0371 - root_mean_squared_error: 0.0533
# Epoch 14/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - mean_absolute_error: 0.0361 - root_mean_squared_error: 0.0516
# Epoch 15/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0374 - root_mean_squared_error: 0.0542
# Epoch 16/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0357 - root_mean_squared_error: 0.0528
# Epoch 17/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0366 - root_mean_squared_error: 0.0554
# Epoch 18/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0370 - root_mean_squared_error: 0.0533
# Epoch 19/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - mean_absolute_error: 0.0357 - root_mean_squared_error: 0.0511
# Epoch 20/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0368 - root_mean_squared_error: 0.0532
# Epoch 21/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - mean_absolute_error: 0.0365 - root_mean_squared_error: 0.0521
# Epoch 22/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - mean_absolute_error: 0.0351 - root_mean_squared_error: 0.0518
# Epoch 23/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - mean_absolute_error: 0.0325 - root_mean_squared_error: 0.0471
# Epoch 24/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - mean_absolute_error: 0.0330 - root_mean_squared_error: 0.0498
# Epoch 25/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - mean_absolute_error: 0.0332 - root_mean_squared_error: 0.0507
# Epoch 26/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - mean_absolute_error: 0.0335 - root_mean_squared_error: 0.0483
# Epoch 27/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - mean_absolute_error: 0.0328 - root_mean_squared_error: 0.0471
# Epoch 28/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - mean_absolute_error: 0.0324 - root_mean_squared_error: 0.0479
# Epoch 29/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - mean_absolute_error: 0.0358 - root_mean_squared_error: 0.0520
# Epoch 30/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - mean_absolute_error: 0.0329 - root_mean_squared_error: 0.0479
# Epoch 31/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - mean_absolute_error: 0.0325 - root_mean_squared_error: 0.0472
# Epoch 32/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - mean_absolute_error: 0.0337 - root_mean_squared_error: 0.0491
# Epoch 33/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - mean_absolute_error: 0.0326 - root_mean_squared_error: 0.0468
# Epoch 34/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - mean_absolute_error: 0.0334 - root_mean_squared_error: 0.0509
# Epoch 35/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - mean_absolute_error: 0.0331 - root_mean_squared_error: 0.0488
# Epoch 36/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - mean_absolute_error: 0.0316 - root_mean_squared_error: 0.0472
# Epoch 37/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - mean_absolute_error: 0.0315 - root_mean_squared_error: 0.0468
# Epoch 38/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0021 - mean_absolute_error: 0.0308 - root_mean_squared_error: 0.0456
# Epoch 39/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - mean_absolute_error: 0.0331 - root_mean_squared_error: 0.0488
# Epoch 40/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - mean_absolute_error: 0.0337 - root_mean_squared_error: 0.0493
# Epoch 41/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - mean_absolute_error: 0.0313 - root_mean_squared_error: 0.0470
# Epoch 42/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - mean_absolute_error: 0.0325 - root_mean_squared_error: 0.0494
# Epoch 43/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - mean_absolute_error: 0.0320 - root_mean_squared_error: 0.0466
# Epoch 44/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - mean_absolute_error: 0.0333 - root_mean_squared_error: 0.0495
# Epoch 45/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0021 - mean_absolute_error: 0.0316 - root_mean_squared_error: 0.0458
# Epoch 46/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - mean_absolute_error: 0.0329 - root_mean_squared_error: 0.0488
# Epoch 47/100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0339 - root_mean_squared_error: 0.0520
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012 - mean_absolute_error: 0.0225 - root_mean_squared_error: 0.0344
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - loss: 0.0017 - mean_absolute_error: 0.0281 - root_mean_squared_error: 0.0410

# %%
predictions = model.predict(X_test)

actual_values = np.array(Y_test).reshape(-1,1)
predicted_values = np.array(predictions).reshape(-1,1)
actual_values_unscaled = scaler.inverse_transform(actual_values)
predicted_values_unscaled = scaler.inverse_transform(predicted_values)
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# Calculate the metrics
mse = mean_squared_error(actual_values_unscaled, predicted_values_unscaled)
rmse = np.sqrt(mse)
mae = mean_absolute_error(actual_values_unscaled, predicted_values_unscaled)

# Print the metrics (optional)
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Mean Absolute Error (MAE): {mae}')

# Create a DataFrame to hold the metrics
metrics_df = pd.DataFrame({
    'Metric': ['MSE', 'RMSE', 'MAE'],
    'Value': [mse, rmse, mae]
})

# Save the DataFrame to a CSV file
metrics_df.to_csv('metrics_LSTM.csv', index=False)

# Print confirmation (optional)
print('Metrics saved to metrics_LSTM.csv')
# Out:
# Mean Squared Error (MSE): 644.70166015625
# Root Mean Squared Error (RMSE): 25.390975952148438
# Mean Absolute Error (MAE): 14.498278617858887
# Metrics saved to metrics_LSTM.csv

# %%
df
# Out:
#                      DHH        kW/h
# 0    2021-01-01 00:00:00  250.770004
# 1    2021-01-01 01:00:00  231.770004
# 2    2021-01-01 02:00:00  222.869995
# 3    2021-01-01 03:00:00  221.369995
# 4    2021-01-01 04:00:00  220.429993
# ...                  ...         ...
# 4219 2021-06-25 19:00:00  456.130005
# 4220 2021-06-25 20:00:00  502.700012
# 4221 2021-06-25 21:00:00  533.200012
# 4222 2021-06-25 22:00:00  526.369995
# 4223 2021-06-25 23:00:00  517.599976
#
# [4224 rows x 2 columns]

# %%
plt.figure(figsize=(20,10))
plt.plot(actual_values_unscaled, label='Actual')
plt.plot(predicted_values_unscaled, label='Predicted')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14, 7))
plt.plot(test_dates, actual_values_unscaled, label='Actual Consumption', color='blue')
plt.plot(test_dates, predicted_values_unscaled, label='Predicted Consumption', color='orange')

plt.xlabel('Date')
plt.ylabel('Energy Consumption (kW/h)')
plt.title('Tilos Island Total Energy Consumption - Test Data - LSTM Model')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 plt.figure(figsize=(14, 7))
# ----> 2 plt.plot(test_dates, actual_values_unscaled, label='Actual Consumption', color='blue')
#       3 plt.plot(test_dates, predicted_values_unscaled, label='Predicted Consumption', color='orange')
#       5 plt.xlabel('Date')
#
# NameError: name 'test_dates' is not defined

# %%
# i want to plot the original dataframe timeseries by setting the index to the 'DHH' column
#df = df.set_index('DHH')
plt.figure(figsize=(20,10))
plt.title('Tilos Island Total Energy Consumption')
plt.xlabel('Date')
plt.ylabel('Electricity Consumption (kW/h)')
plt.plot(df)
plt.show()

# %%
df
# Out:
#                      DHH        kW/h
# 0    2021-01-01 00:00:00  250.770004
# 1    2021-01-01 01:00:00  231.770004
# 2    2021-01-01 02:00:00  222.869995
# 3    2021-01-01 03:00:00  221.369995
# 4    2021-01-01 04:00:00  220.429993
# ...                  ...         ...
# 4219 2021-06-25 19:00:00  456.130005
# 4220 2021-06-25 20:00:00  502.700012
# 4221 2021-06-25 21:00:00  533.200012
# 4222 2021-06-25 22:00:00  526.369995
# 4223 2021-06-25 23:00:00  517.599976
#
# [4224 rows x 2 columns]

# %%
actual_values_unscaled
# Out:
# array([[277.97   ],
#        [298.     ],
#        [309.7    ],
#        [282.57   ],
#        [253.2    ],
#        [219.63   ],
#        [213.5    ],
#        [203.33   ],
#        [194.16998],
#        [191.87   ],
#        [187.36   ],
#        [181.6    ],
#        [194.57   ],
#        [189.6    ],
#        [165.2    ],
#        [168.5    ],
#        [154.43   ],
#        [158.86998],
#        [123.17   ],
#        [118.     ],
#        [104.73001],
#        [116.53   ],
#        [163.36   ],
#        [246.7    ],
#        [289.63   ],
#        [303.53   ],
#        [320.     ],
#        [287.2    ],
#        [256.77   ],
#        [222.36998],
#        [215.1    ],
#        [209.27   ],
#        [198.83   ],
#        [194.9    ],
#        [193.43   ],
#        [194.63   ],
#        [224.3    ],
#        [227.26999],
#        [203.43   ],
#        [186.     ],
#        [166.82999],
#        [156.47   ],
#        [175.63   ],
#        [140.67   ],
#        [141.37   ],
#        [163.33   ],
#        [212.3    ],
#        [267.3    ],
#        [310.07   ],
#        [327.7    ],
#        [340.73   ],
#        [313.8    ],
#        [276.53   ],
#        [252.     ],
#        [241.87   ],
#        [223.83   ],
#        [213.3    ],
#        [207.57   ],
#        [203.73   ],
#        [211.     ],
#        [225.26999],
#        [225.70001],
#        [206.7    ],
#        [184.97   ],
#        [169.33   ],
#        [167.     ],
#        [159.10002],
#        [157.47   ],
#        [163.67   ],
#        [187.96999],
#        [234.83   ],
#        [271.8    ],
#        [316.43   ],
#        [332.80002],
#        [360.63   ],
#        [326.67004],
#        [298.9    ],
#        [262.9    ],
#        [244.23   ],
#        [230.32999],
#        [223.83   ],
#        [219.17   ],
#        [219.77   ],
#        [224.43   ],
#        [238.3    ],
#        [238.80002],
#        [236.17   ],
#        [255.9    ],
#        [231.43001],
#        [285.8    ],
#        [289.2    ],
#        [279.87   ],
#        [200.73   ],
#        [172.44   ],
#        [270.93   ],
#        [308.32996],
#        [332.7    ],
#        [336.93   ],
#        [345.93   ],
#        [329.23   ],
#        [290.3    ],
#        [264.87   ],
#        [243.13   ],
#        [225.97   ],
#        [219.33   ],
#        [215.2    ],
#        [214.77   ],
#        [219.5    ],
#        [235.8    ],
#        [239.6    ],
#        [218.8    ],
#        [198.83   ],
#        [187.9    ],
#        [164.47   ],
#        [148.9    ],
#        [138.13   ],
#        [141.57   ],
#        [150.20001],
#        [212.7    ],
#        [281.2    ],
#        [321.33   ],
#        [330.63   ],
#        [335.5    ],
#        [326.97   ],
#        [293.8    ],
#        [275.2    ],
#        [258.83   ],
#        [234.3    ],
#        [218.1    ],
#        [210.59999],
#        [219.63   ],
#        [225.8    ],
#        [265.43   ],
#        [243.63   ],
#        [214.17001],
#        [177.7    ],
#        [168.67   ],
#        [159.63   ],
#        [133.3    ],
#        [127.27   ],
#        [202.59999],
#        [246.52998],
#        [276.27   ],
#        [305.96997],
#        [316.93   ],
#        [326.97   ],
#        [340.5    ],
#        [317.96997],
#        [301.02997],
#        [271.73   ],
#        [261.1    ],
#        [241.63   ],
#        [229.7    ],
#        [226.17001],
#        [225.5    ],
#        [221.07002],
#        [239.2    ],
#        [263.7    ],
#        [275.07   ],
#        [241.73   ],
#        [180.27   ],
#        [146.7    ],
#        [134.03   ],
#        [134.43   ],
#        [127.73   ],
#        [154.8    ],
#        [199.69998],
#        [267.     ],
#        [321.23   ],
#        [332.73   ],
#        [334.33   ],
#        [315.63   ],
#        [292.7    ],
#        [261.63   ],
#        [247.07   ],
#        [229.17   ],
#        [221.3    ],
#        [220.87   ],
#        [219.5    ],
#        [214.2    ],
#        [225.63   ],
#        [222.17001],
#        [213.87   ],
#        [235.23   ],
#        [254.47   ],
#        [262.97   ],
#        [255.33   ],
#        [203.57   ],
#        [204.97   ],
#        [220.17001],
#        [251.1    ],
#        [305.83   ],
#        [310.93   ],
#        [320.67   ],
#        [330.53   ],
#        [307.83   ],
#        [274.6    ],
#        [249.07   ],
#        [230.4    ],
#        [224.36998],
#        [217.2    ],
#        [215.89998],
#        [205.     ],
#        [206.5    ],
#        [244.13   ],
#        [240.     ],
#        [214.1    ],
#        [177.49998],
#        [143.6    ],
#        [140.13   ],
#        [123.57   ],
#        [125.47   ],
#        [124.6    ],
#        [140.1    ],
#        [192.33   ],
#        [245.67   ],
#        [280.27   ],
#        [307.33   ],
#        [324.03   ],
#        [289.47   ],
#        [262.93   ],
#        [252.7    ],
#        [238.7    ],
#        [237.03   ],
#        [225.87   ],
#        [220.27   ],
#        [214.9    ],
#        [216.87   ],
#        [236.57   ],
#        [228.79999],
#        [231.6    ],
#        [191.07   ],
#        [167.     ],
#        [139.13   ],
#        [161.8    ],
#        [255.73   ],
#        [232.67   ],
#        [241.63   ],
#        [258.13   ],
#        [286.23   ],
#        [307.     ],
#        [322.77   ],
#        [333.13   ],
#        [299.8    ],
#        [275.63   ],
#        [248.63   ],
#        [240.23   ],
#        [231.17   ],
#        [218.17001],
#        [220.67   ],
#        [222.2    ],
#        [226.3    ],
#        [240.23   ],
#        [243.46999],
#        [205.27   ],
#        [162.27   ],
#        [146.87   ],
#        [145.37   ],
#        [132.07   ],
#        [118.27   ],
#        [122.2    ],
#        [134.53   ],
#        [180.67   ],
#        [236.1    ],
#        [280.47   ],
#        [317.93   ],
#        [319.03   ],
#        [301.23   ],
#        [258.17   ],
#        [255.03   ],
#        [240.99998],
#        [227.5    ],
#        [211.43   ],
#        [218.97   ],
#        [221.3    ],
#        [228.63   ],
#        [254.33002],
#        [259.33   ],
#        [200.26   ],
#        [175.87   ],
#        [146.87   ],
#        [144.4    ],
#        [128.57   ],
#        [139.8    ],
#        [130.93   ],
#        [132.83   ],
#        [175.49998],
#        [237.7    ],
#        [303.7    ],
#        [322.77   ],
#        [333.23   ],
#        [300.     ],
#        [279.9    ],
#        [260.37   ],
#        [242.1    ],
#        [235.23   ],
#        [228.5    ],
#        [229.87   ],
#        [243.13   ],
#        [237.90001],
#        [258.73   ],
#        [251.03   ],
#        [203.63   ],
#        [166.9    ],
#        [139.03   ],
#        [144.17   ],
#        [146.07   ],
#        [123.6    ],
#        [129.07   ],
#        [134.17   ],
#        [180.47   ],
#        [244.63   ],
#        [303.43   ],
#        [326.73   ],
#        [339.4    ],
#        [305.83   ],
#        [294.9    ],
#        [260.27   ],
#        [249.83   ],
#        [239.2    ],
#        [229.     ],
#        [229.87   ],
#        [235.4    ],
#        [237.13   ],
#        [242.73   ],
#        [242.52998],
#        [202.73   ],
#        [183.13   ],
#        [169.29999],
#        [161.92998],
#        [159.6    ],
#        [147.93   ],
#        [145.87   ],
#        [157.8    ],
#        [185.     ],
#        [256.97   ],
#        [306.7    ],
#        [337.17   ],
#        [342.53   ],
#        [315.4    ],
#        [275.33   ],
#        [261.57   ],
#        [252.93   ],
#        [238.6    ],
#        [228.9    ],
#        [233.     ],
#        [235.1    ],
#        [229.90001],
#        [241.17   ],
#        [241.97   ],
#        [213.89998],
#        [193.3    ],
#        [180.6    ],
#        [166.87001],
#        [160.1    ],
#        [161.     ],
#        [153.5    ],
#        [183.8    ],
#        [206.03   ],
#        [268.67   ],
#        [313.83   ],
#        [337.2    ],
#        [335.03   ],
#        [296.53   ],
#        [274.17   ],
#        [270.83   ],
#        [257.7    ],
#        [249.23   ],
#        [232.03   ],
#        [226.83   ],
#        [233.47   ],
#        [230.83   ],
#        [256.73   ],
#        [259.1    ],
#        [234.43   ],
#        [210.8    ],
#        [179.47   ],
#        [173.53   ],
#        [162.63002],
#        [153.6    ],
#        [182.1    ],
#        [194.93   ],
#        [243.3    ],
#        [298.3    ],
#        [328.87   ],
#        [348.63   ],
#        [378.52997],
#        [340.67   ],
#        [311.6    ],
#        [306.53   ],
#        [288.3    ],
#        [276.43   ],
#        [250.52998],
#        [247.17   ],
#        [259.03   ],
#        [255.73   ],
#        [288.63   ],
#        [286.13   ],
#        [222.47   ],
#        [189.4    ],
#        [187.7    ],
#        [189.93   ],
#        [181.7    ],
#        [177.77002],
#        [179.6    ],
#        [198.27   ],
#        [241.17   ],
#        [288.33   ],
#        [328.73   ],
#        [348.2    ],
#        [370.9    ],
#        [332.93   ],
#        [299.9    ],
#        [276.97   ],
#        [272.     ],
#        [256.57   ],
#        [243.27002],
#        [253.37   ],
#        [259.17   ],
#        [251.77   ],
#        [274.4    ],
#        [223.5    ],
#        [232.27   ],
#        [217.1    ],
#        [196.43   ],
#        [172.37   ],
#        [190.27   ],
#        [190.43   ],
#        [180.9    ],
#        [194.63   ],
#        [236.     ],
#        [289.9    ],
#        [315.7    ],
#        [350.     ],
#        [363.69998],
#        [330.03   ],
#        [296.63004],
#        [281.97   ],
#        [267.93   ],
#        [258.83   ],
#        [251.46999],
#        [250.37   ],
#        [256.87   ],
#        [252.23   ],
#        [278.97   ],
#        [279.6    ],
#        [238.97   ],
#        [213.70001],
#        [211.03   ],
#        [217.70001],
#        [183.4    ],
#        [168.87001],
#        [190.7    ],
#        [206.2    ],
#        [230.73   ],
#        [292.43   ],
#        [348.57   ],
#        [373.47   ],
#        [384.6    ],
#        [345.37   ],
#        [306.1    ],
#        [287.97   ],
#        [287.2    ],
#        [279.5    ],
#        [269.4    ],
#        [265.37   ],
#        [264.53   ],
#        [255.8    ],
#        [274.13   ],
#        [274.87   ],
#        [248.77   ],
#        [226.77   ],
#        [187.57   ],
#        [229.73   ],
#        [196.7    ],
#        [182.87   ],
#        [176.47   ],
#        [199.43   ],
#        [237.7    ],
#        [299.57   ],
#        [334.43   ],
#        [349.3    ],
#        [345.27002],
#        [320.5    ],
#        [296.93   ],
#        [282.8    ],
#        [265.63   ],
#        [272.14   ],
#        [266.8    ],
#        [257.87   ],
#        [259.87   ],
#        [235.57   ],
#        [248.23   ],
#        [251.5    ],
#        [237.97   ],
#        [205.33   ],
#        [185.87   ],
#        [192.9    ],
#        [204.97   ],
#        [180.67   ],
#        [162.5    ],
#        [212.9    ],
#        [253.63   ],
#        [298.57   ],
#        [344.87   ],
#        [367.3    ],
#        [382.17   ],
#        [338.36996],
#        [310.27   ],
#        [290.37   ],
#        [276.5    ],
#        [280.43   ],
#        [265.5    ],
#        [258.63   ],
#        [259.67   ],
#        [ 27.37   ],
#        [  0.     ],
#        [129.27   ],
#        [268.9    ],
#        [252.07   ],
#        [214.5    ],
#        [229.33   ],
#        [222.13002],
#        [197.9    ],
#        [195.50002],
#        [211.97   ],
#        [245.3    ],
#        [309.49997],
#        [344.7    ],
#        [359.57   ],
#        [365.53   ],
#        [336.77   ],
#        [312.     ],
#        [281.03   ],
#        [262.     ],
#        [262.53   ],
#        [270.03   ],
#        [261.23   ],
#        [263.5    ],
#        [255.13   ],
#        [270.77   ],
#        [262.37   ],
#        [216.2    ],
#        [221.5    ],
#        [208.93   ],
#        [191.1    ],
#        [184.5    ],
#        [189.9    ],
#        [179.33   ],
#        [209.97   ],
#        [221.67   ],
#        [286.6    ],
#        [349.37   ],
#        [383.77   ],
#        [378.52997],
#        [349.73   ],
#        [319.63   ],
#        [300.03   ],
#        [279.67   ],
#        [272.07   ],
#        [275.2    ],
#        [266.73   ],
#        [265.53   ],
#        [252.     ],
#        [279.2    ],
#        [269.47   ],
#        [261.1    ],
#        [223.42998],
#        [200.83   ],
#        [177.33   ],
#        [175.07   ],
#        [159.53   ],
#        [172.23   ],
#        [190.97   ],
#        [238.77   ],
#        [291.     ],
#        [319.03   ],
#        [342.43   ],
#        [350.53   ],
#        [329.89996],
#        [305.13   ],
#        [291.4    ],
#        [269.     ],
#        [271.1    ],
#        [269.03   ],
#        [255.77   ],
#        [ 48.9    ],
#        [169.4    ],
#        [280.87   ],
#        [269.6    ],
#        [235.93   ],
#        [199.8    ],
#        [181.2    ],
#        [228.5    ],
#        [301.7    ],
#        [289.67   ],
#        [283.4    ],
#        [294.13   ],
#        [303.9    ],
#        [319.6    ],
#        [328.43   ],
#        [345.93   ],
#        [374.9    ],
#        [351.5    ],
#        [311.6    ],
#        [299.87   ],
#        [282.2    ],
#        [271.17   ],
#        [260.63   ],
#        [254.57   ],
#        [258.37   ],
#        [248.87   ],
#        [264.9    ],
#        [265.63   ],
#        [245.46999],
#        [215.06999],
#        [191.43   ],
#        [197.57   ],
#        [192.63   ],
#        [182.73   ],
#        [177.13   ],
#        [212.17001],
#        [257.13   ],
#        [305.10004],
#        [355.07004],
#        [364.3    ],
#        [369.6    ],
#        [358.87   ],
#        [336.23   ],
#        [316.     ],
#        [296.8    ],
#        [290.93   ],
#        [280.53   ],
#        [270.27   ],
#        [271.4    ],
#        [267.5    ],
#        [278.77   ],
#        [279.47   ],
#        [252.9    ],
#        [221.07002],
#        [215.42998],
#        [223.93   ],
#        [203.63   ],
#        [202.47   ],
#        [216.5    ],
#        [238.1    ],
#        [273.2    ],
#        [322.4    ],
#        [365.03   ],
#        [416.67   ],
#        [445.7    ],
#        [405.33   ],
#        [370.27   ],
#        [348.57   ],
#        [334.3    ],
#        [321.33   ],
#        [302.73   ],
#        [296.17   ],
#        [293.33   ],
#        [285.4    ],
#        [ 95.27   ],
#        [ 62.63   ],
#        [348.80002],
#        [325.17   ],
#        [291.     ],
#        [248.93   ],
#        [247.97   ],
#        [247.03   ],
#        [257.7    ],
#        [261.27   ],
#        [319.4    ],
#        [349.13   ],
#        [389.4    ],
#        [406.87   ],
#        [435.79996],
#        [404.7    ],
#        [390.8    ],
#        [365.7    ],
#        [344.73   ],
#        [349.67   ],
#        [343.5    ],
#        [331.63   ],
#        [309.17   ],
#        [280.6    ],
#        [292.87   ],
#        [300.32996],
#        [308.2    ],
#        [295.93002],
#        [275.47   ],
#        [254.     ],
#        [255.57   ],
#        [242.27   ],
#        [242.     ],
#        [293.2    ],
#        [321.4    ],
#        [375.4    ],
#        [426.53   ],
#        [434.63   ],
#        [435.7    ],
#        [422.23   ],
#        [401.5    ],
#        [381.57   ],
#        [362.99997],
#        [355.69998],
#        [339.6    ],
#        [316.7    ],
#        [296.5    ],
#        [288.1    ],
#        [290.53   ],
#        [302.     ],
#        [284.1    ],
#        [240.07   ],
#        [228.23   ],
#        [223.89998],
#        [255.67   ],
#        [233.73   ],
#        [230.2    ],
#        [278.6    ],
#        [297.8    ],
#        [344.     ],
#        [388.37   ],
#        [430.3    ],
#        [442.73   ],
#        [422.7    ],
#        [390.47   ],
#        [362.60004],
#        [341.53   ],
#        [335.27   ],
#        [314.9    ],
#        [295.23   ],
#        [296.27   ],
#        [289.43   ],
#        [302.19998],
#        [297.     ],
#        [296.07   ],
#        [286.     ],
#        [269.43   ],
#        [265.8    ],
#        [272.77   ],
#        [283.7    ],
#        [268.83   ],
#        [284.1    ],
#        [310.1    ],
#        [344.80002],
#        [383.17   ],
#        [430.7    ],
#        [462.23   ],
#        [428.2    ],
#        [414.8    ],
#        [395.07   ],
#        [366.03   ],
#        [340.3    ],
#        [317.7    ],
#        [308.47   ],
#        [308.40002],
#        [295.     ],
#        [324.27   ],
#        [330.87   ],
#        [329.26996],
#        [302.37   ],
#        [282.2    ],
#        [277.73   ],
#        [299.63   ],
#        [311.27   ],
#        [306.53   ],
#        [319.67   ],
#        [352.3    ],
#        [403.53   ],
#        [435.07   ],
#        [447.03   ],
#        [472.     ],
#        [471.03   ],
#        [452.17   ],
#        [443.77   ],
#        [410.87   ],
#        [381.77   ],
#        [354.1    ],
#        [346.5    ],
#        [339.97   ],
#        [322.33   ],
#        [257.23   ],
#        [342.83   ],
#        [346.2    ],
#        [312.17   ],
#        [293.77   ],
#        [304.40002],
#        [318.77   ],
#        [299.33   ],
#        [323.97   ],
#        [335.63   ],
#        [366.99997],
#        [417.77   ],
#        [439.1    ],
#        [470.83   ],
#        [497.29996],
#        [485.13004],
#        [468.     ],
#        [444.13   ],
#        [421.37   ],
#        [389.43002],
#        [356.5    ],
#        [347.33   ],
#        [339.4    ],
#        [235.2    ],
#        [363.3    ],
#        [364.67   ],
#        [339.8    ],
#        [324.43   ],
#        [307.     ],
#        [316.77   ],
#        [316.93   ],
#        [336.43   ],
#        [321.83   ],
#        [343.43   ],
#        [395.86996],
#        [420.13   ],
#        [456.13   ],
#        [502.70004],
#        [533.2    ],
#        [526.37   ],
#        [517.6    ]], dtype=float32)

# %%
df.info
# Out:
# <bound method DataFrame.info of                            kW/h
# DHH
# 2021-01-01 00:00:00  250.770004
# 2021-01-01 01:00:00  231.770004
# 2021-01-01 02:00:00  222.869995
# 2021-01-01 03:00:00  221.369995
# 2021-01-01 04:00:00  220.429993
# ...                         ...
# 2021-06-25 19:00:00  456.130005
# 2021-06-25 20:00:00  502.700012
# 2021-06-25 21:00:00  533.200012
# 2021-06-25 22:00:00  526.369995
# 2021-06-25 23:00:00  517.599976
#
# [4224 rows x 1 columns]>

# %%
plt.figure(figsize=(14, 7))
plt.plot(df['DHH'], df['kW/h'], label='Actual kW/h consumed', color='blue')
plt.plot(df['DHH'][-len(predicted_values_unscaled):], predicted_values_unscaled, label='Predicted kW/h consumed', color='red', linestyle='dashed')

plt.xlabel('Date')
plt.ylabel('kW/h Consumed')
plt.title('Tilos Island Total Energy Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\verxus\projects\enpower\tilos-fc\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DHH'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 2
#       1 plt.figure(figsize=(14, 7))
# ----> 2 plt.plot(df['DHH'], df['kW/h'], label='Actual kW/h consumed', color='blue')
#       3 plt.plot(df['DHH'][-len(predicted_values_unscaled):], predicted_values_unscaled, label='Predicted kW/h consumed', color='red', linestyle='dashed')
#       5 plt.xlabel('Date')
#
# File c:\Users\verxus\projects\enpower\tilos-fc\.venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\verxus\projects\enpower\tilos-fc\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'DHH'

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Assuming `scaler` and `model` are already defined
# Assuming `X_test`, `Y_test` are already defined

predictions = model.predict(X_test)

actual_values = np.array(Y_test).reshape(-1,1)
predicted_values = np.array(predictions).reshape(-1,1)
actual_values_unscaled = scaler.inverse_transform(actual_values)
predicted_values_unscaled = scaler.inverse_transform(predicted_values)

# Load the data

# Ensure the test data part is aligned with the original dataframe
test_dates = df['DHH'][-len(actual_values_unscaled):]

# Plotting the test data results
plt.figure(figsize=(14, 7))
plt.plot(test_dates, actual_values_unscaled, label='Actual Consumption', color='blue')
plt.plot(test_dates, predicted_values_unscaled, label='Predicted Consumption', color='orange')

plt.xlabel('Date')
plt.ylabel('Energy Consumption (kW/h)')
plt.title('Tilos Island Total Energy Consumption - Test Data - LSTM Model')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
